# %%
# !git clone https://github.com/shahrushi2003/CLAP.git
# %cd /kaggle/working/CLAP
# Out:
# Cloning into 'CLAP'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (296/296), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 296 (delta 155), reused 260 (delta 130), pack-reused 0
# Receiving objects: 100% (296/296), 505.39 KiB | 4.04 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
# !pip install .
# Out:
# Processing /kaggle/working/CLAP
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for msclap: filename=msclap-1.3.3-py3-none-any.whl size=31140 sha256=5fef9ecfa8c27f676c61b36cc8c6a07f9e34ebde5e26199d85ef26ceb27c478a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w2qg2oqq/wheels/1a/84/f9/e98718fe6db1cdba6f242049f68f73aeb33e2b2d1bead08e37
# Successfully built msclap
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python main.py
# Out:
# Exception Occurred!
